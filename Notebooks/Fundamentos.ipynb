# %%
print('maça', 'pera', sep='-')
# Out:
# maça-pera

# %%
print('maçã ', end='fim')
# Out:
# maçã fim

# %%
print("Maçã", "Pera", end=" fim", sep=" ")
# Out:
# Maçã Pera fim

# %%
print("este é um texto longo, \neu quero quebrar a linha")
# Out:
# este é um texto longo,
# eu quero quebrar a linha

# %%
print("Maçã", "Pera", sep="\n")
# Out:
# Maçã
# Pera

# %%
print("A pontuação total de %s foi %s pontos" %("Aleff", "10"))
# Out:
# A pontuação total de Aleff foi 10 pontos

# %%
print("A pontuação total de {} foi {} pronto".format("Aleff","10"))
# Out:
# A pontuação total de Aleff foi 10 pronto

# %%
print("A pontuação total de" +" Fernando " + "foi " + "10 " + "Pontos")
# Out:
# A pontuação total de Fernando foi 10 Pontos
